# %%
def divisors(n):
    r=0
    for i in range(1,n):
        if not n%i:
            r+=1
    return r

div
# Out:
# 3
# 7
# 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-b71e68fb54f3> in <module>
#      19 items=[1,2,3,4,5,6,7]
#      20 k=3
# ---> 21 josephus(items,k)
#
# <ipython-input-14-b71e68fb54f3> in josephus(items, k)
#       7
#       8             index+=k
# ----> 9             print(items[index])
#      10             r.append(items.pop(index))
#      11
#
# IndexError: list index out of range

# %%
# Out:
# 5
