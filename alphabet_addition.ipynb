# %%
def add_letters(*letters):
    if not len(letters):
        return "z"
    r=0
    for v in letters:
        r+=(ord(v)-96)
    if not r%26: r=
    return chr(97 + r%26)

# %%
ord("a")
# Out:
# 97
